# %% [markdown]
# <a href="https://colab.research.google.com/github/Makailo/Quantum-Computing/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

enlaces = [(0,1),(0,2), (0,3), (0,4), (1,2), (1,3), (2,3), (2,4)]

pesos

matrix = np.zeros([5,5])


for enlace in enlaces:
  matrix[enlace[0], enlace[1]] = 1
  matrix[enlace[1], enlace[0]] = 1

matrix

QUBO_def = {(f"x_{i1}_{t1}", f"x_{i2}_{t2}"):0 for i1 in range(5) for i2 in range(i1, 5) for t1 in range(5) for t2 in range(5)}
QUBO_def
# Out:
# {('x_0_0', 'x_0_0'): 0,
#  ('x_0_0', 'x_0_1'): 0,
#  ('x_0_0', 'x_0_2'): 0,
#  ('x_0_0', 'x_0_3'): 0,
#  ('x_0_0', 'x_0_4'): 0,
#  ('x_0_1', 'x_0_0'): 0,
#  ('x_0_1', 'x_0_1'): 0,
#  ('x_0_1', 'x_0_2'): 0,
#  ('x_0_1', 'x_0_3'): 0,
#  ('x_0_1', 'x_0_4'): 0,
#  ('x_0_2', 'x_0_0'): 0,
#  ('x_0_2', 'x_0_1'): 0,
#  ('x_0_2', 'x_0_2'): 0,
#  ('x_0_2', 'x_0_3'): 0,
#  ('x_0_2', 'x_0_4'): 0,
#  ('x_0_3', 'x_0_0'): 0,
#  ('x_0_3', 'x_0_1'): 0,
#  ('x_0_3', 'x_0_2'): 0,
#  ('x_0_3', 'x_0_3'): 0,
#  ('x_0_3', 'x_0_4'): 0,
#  ('x_0_4', 'x_0_0'): 0,
#  ('x_0_4', 'x_0_1'): 0,
#  ('x_0_4', 'x_0_2'): 0,
#  ('x_0_4', 'x_0_3'): 0,
#  ('x_0_4', 'x_0_4'): 0,
#  ('x_0_0', 'x_1_0'): 0,
#  ('x_0_0', 'x_1_1'): 0,
#  ('x_0_0', 'x_1_2'): 0,
#  ('x_0_0', 'x_1_3'): 0,
#  ('x_0_0', 'x_1_4'): 0,
#  ('x_0_1', 'x_1_0'): 0,
#  ('x_0_1', 'x_1_1'): 0,
#  ('x_0_1', 'x_1_2'): 0,
#  ('x_0_1', 'x_1_3'): 0,
#  ('x_0_1', 'x_1_4'): 0,
#  ('x_0_2', 'x_1_0'): 0,
#  ('x_0_2', 'x_1_1'): 0,
#  ('x_0_2', 'x_1_2'): 0,
# ...

# %%
lagrange = 10


for t in range(5):

  for i1 in range(5):

    QUBO_def[(f"x_{i1}_{t}",f"x_{i1}_{t}")] -= lagrange

    for i2 in range(i1 + 1, 5):
      QUBO_def[(f"x_{i1}_{t}",f"x_{i2}_{t}")] += 2 * lagrange


for i in range(5):

  for t1 in range(5):

    QUBO_def[(f"x_{i}_{t1}",f"x_{i}_{t1}")] -= lagrange

    for t2 in range(t1 + 1, 5):
      QUBO_def[(f"x_{i}_{t1}",f"x_{i}_{t2}")] += 2 * lagrange

# %%
# !pip install dwave-ocean-sdk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.4/111.4 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 56.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 71.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 72.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 5.0 MB/s eta 0:00:00
# ...

# %%
print(len(QUBO_def))
from neal import SimulatedAnnealingSampler

sampler = SimulatedAnnealingSampler()
sampleset = sampler.sample_qubo(QUBO_def, num_read = 3000)
print(sampleset.first)
# Out:
# 375
# Sample(sample={'x_0_0': 0, 'x_0_1': 0, 'x_0_2': 1, 'x_0_3': 0, 'x_0_4': 0, 'x_1_0': 1, 'x_1_1': 0, 'x_1_2': 0, 'x_1_3': 0, 'x_1_4': 0, 'x_2_0': 0, 'x_2_1': 0, 'x_2_2': 0, 'x_2_3': 0, 'x_2_4': 1, 'x_3_0': 0, 'x_3_1': 0, 'x_3_2': 0, 'x_3_3': 1, 'x_3_4': 0, 'x_4_0': 0, 'x_4_1': 1, 'x_4_2': 0, 'x_4_3': 0, 'x_4_4': 0}, energy=-100.0, num_occurrences=1)

# %%
solucion = sampleset.first[0]
for x in solucion:
  if solucion[x] == 1:
    print(x)
# Out:
# x_0_2
# x_1_0
# x_2_4
# x_3_3
# x_4_1
